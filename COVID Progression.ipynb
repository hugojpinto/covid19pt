# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline


# Read data from file 'filename.csv' 
# (in the same directory that your python process is based)
# Control delimiters, rows, column names with read_csv (see later) 
df = pd.read_csv("portugal.csv") 
# Preview the first 5 lines of the loaded data 
df.head(20)
# Out:
#           date  confirmados  infirmados  aguardam  suspeitos  vigiados  \
# 0   02/03/2020          2.0         NaN       NaN       85.0       NaN
# 1   03/03/2020          5.0         NaN       NaN      101.0       NaN
# 2   04/03/2020          6.0         NaN       NaN      117.0       NaN
# 3   05/03/2020          9.0         NaN       NaN      167.0       NaN
# 4   06/03/2020         13.0         NaN       NaN      181.0       NaN
# 5   07/03/2020         21.0         NaN       NaN      224.0       NaN
# 6   08/03/2020         30.0         NaN       NaN      281.0       NaN
# 7   09/03/2020         39.0         NaN       NaN      339.0       NaN
# 8   10/03/2020         41.0         NaN       NaN      375.0       NaN
# 9   11/03/2020         59.0         NaN       NaN      471.0       NaN
# 10  12/03/2020         78.0       426.0     133.0      637.0    4923.0
# 11  13/03/2020        112.0      1024.0     172.0     1308.0    5674.0
# 12  14/03/2020        169.0      1409.0     126.0     1704.0    5011.0
# 13  15/03/2020        245.0      1746.0     281.0     2271.0    4592.0
# 14  16/03/2020        331.0      2203.0     374.0     2908.0    4592.0
# 15  17/03/2020        448.0      3259.0     323.0     4030.0    6852.0
# 16  18/03/2020        642.0      4074.0     351.0     5067.0    6656.0
# 17  19/03/2020        785.0      4788.0     488.0     6061.0    8091.0
# 18  20/03/2020       1020.0      5862.0     850.0     7732.0    9008.0
# 19  21/03/2020       1280.0      7515.0    1059.0     9854.0   13155.0
#
#     mortos  recuperados  internados   uci
# 0      NaN          NaN         NaN   NaN
# 1      NaN          NaN         NaN   NaN
# 2      NaN          NaN         NaN   NaN
# 3      NaN          NaN         NaN   NaN
# 4      NaN          NaN         NaN   NaN
# 5      NaN          NaN         NaN   NaN
# 6      NaN          NaN         NaN   NaN
# 7      NaN          NaN         NaN   NaN
# 8      NaN          NaN         NaN   NaN
# 9      NaN          NaN         NaN   NaN
# 10     0.0          0.0        69.0   NaN
# 11     0.0          0.0       107.0   NaN
# 12     0.0          1.0       114.0  10.0
# 13     0.0          2.0       139.0   9.0
# 14     1.0          3.0       139.0  18.0
# 15     1.0          3.0       206.0  17.0
# 16     1.0          3.0        80.0  20.0
# 17     3.0          3.0        89.0  20.0
# 18     6.0          3.0       126.0  26.0
# 19    12.0          5.0       156.0  35.0

# %%
df['date'] = pd.to_datetime(df.date)
sns.lineplot(data=data, x='date',y='mortos')
sns.lineplot(data=data, x='date',y='recuperados')
